# %% [markdown]
# # w9_all.ipynb — RETIRED
#
# Split into **`w9_a100.ipynb`** (big jobs: anchor_cap >= 2048) and
# **`w9_l40.ipynb`** (small jobs: g512 arms + all CV). The job table moved to
# `pod/w9_jobs.py`; labels/claims/result names are unchanged, so results from
# old w9_all runs are fully recognized and never re-run. Open one of the two
# new notebooks instead.
